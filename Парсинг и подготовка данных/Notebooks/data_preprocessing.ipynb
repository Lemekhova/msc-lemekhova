# %% [markdown]
# # Обрабатываем собранные данные

# %%
import pandas as pd

# %% [markdown]
# Объединяем собранные таблицы

# %%
# Класс auto
auto_1 = pd.read_csv('auto.csv')
auto_2 = pd.read_csv('autonews.csv')
auto_3 = pd.read_csv('dp_auto.csv')

# %%
auto = pd.concat([auto_1, auto_2, auto_3], ignore_index=True)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12878 entries, 0 to 12877
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    12878 non-null  object
#  1   label   12878 non-null  object
# dtypes: object(2)
# memory usage: 201.3+ KB

# %%
# удаляем дубликаты строк
df_auto = auto.drop_duplicates(subset=['text'], keep='first')
df_auto.shape
# Out:
# (12496, 2)

# %%
# Класс finances
finances_1 = pd.read_csv('finances.csv')
finances_2 = pd.read_csv('dp_finances_banks.csv')
finances_3 = pd.read_csv('dp_finances.csv')

# %%
finances = pd.concat([finances_1, finances_2, finances_3], ignore_index=True)

# %%
finances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11054 entries, 0 to 11053
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11054 non-null  object
#  1   label   11054 non-null  object
# dtypes: object(2)
# memory usage: 172.8+ KB

# %%
# удаляем дубликаты строк
df_finances = finances.drop_duplicates(subset=['text'], keep='first')
df_finances.shape
# Out:
# (10751, 2)

# %%
# Класс realty
realty_1 = pd.read_csv('realty.csv')
realty_2 = pd.read_csv('dp_realty.csv')
realty_3 = pd.read_csv('dp_realty_1.csv')
realty_4 = pd.read_csv('dp_realty_2.csv')

# %%
realty = pd.concat([realty_1, realty_2, realty_3, realty_4], ignore_index=True)

# %%
realty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13060 entries, 0 to 13059
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    13060 non-null  object
#  1   label   13060 non-null  object
# dtypes: object(2)
# memory usage: 204.2+ KB

# %%
# удаляем дубликаты строк
df_realty = realty.drop_duplicates(subset=['text'], keep='first')
df_realty.shape
# Out:
# (11302, 2)

# %%
# Класс sport
sport_1 = pd.read_csv('sport_60.csv')
sport_2 = pd.read_csv('sport_60__new.csv')
sport_3 = pd.read_csv('sport_120.csv')
sport_4 = pd.read_csv('sport_180.csv')
sport_5 = pd.read_csv('sport_250.csv')

# %%
sport = pd.concat([sport_1, sport_2, sport_3, sport_4, sport_5], ignore_index=True)

# %%
sport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12710 entries, 0 to 12709
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    12710 non-null  object
#  1   label   12710 non-null  object
# dtypes: object(2)
# memory usage: 198.7+ KB

# %%
# удаляем дубликаты строк
df_sport = sport.drop_duplicates(subset=['text'], keep='first')
df_sport.shape
# Out:
# (10275, 2)

# %%
result = pd.concat([df_sport, df_finances, df_realty, df_auto], ignore_index=True)

# %%
# Удаляем строки, где text == 'Новости компаний'
df_filtered = df[df['text'] != 'Новости компаний']

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43860 entries, 0 to 44823
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    43860 non-null  object
#  1   label   43860 non-null  object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %%
# Удалим фразы (авторов статей и явно указывающие на тему слова - рубрики
# или часто повторяющиеся и не относящиеся к теме, например - "фото", "видео").
# Из-за них часть заголовков может дублироваться, но счтаться разными, т.к. в одном месте есть это слово, в другом нет
df_filtered['text'] = df_filtered['text'].str.replace('Денис Шубин:', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('Александр Холодов. Автоправо:', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('Тестдрайв:', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('Александр Исаев. Страхование.:', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('Надежда Кузнецова. Налоги.:', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('Юрий Берхман. Страхование: ', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('(фото)', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('(фотоб видео)', '', regex=False)
df_filtered['text'] = df_filtered['text'].str.replace('(видео)', '', regex=False)
# Out:
# /tmp/ipykernel_5927/1443617224.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['text'] = df_filtered['text'].str.replace('Денис Шубин:', '', regex=False)
# /tmp/ipykernel_5927/1443617224.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['text'] = df_filtered['text'].str.replace('Александр Холодов. Автоправо:', '', regex=False)
# /tmp/ipykernel_5927/1443617224.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# удаляем дубликаты строк
df = result.drop_duplicates(subset=['text'])

# %%
result.shape
# Out:
# (44824, 2)

# %%
df.shape
# Out:
# (43860, 2)

# %%
df_filtered.shape
# Out:
# (43859, 2)

# %%
# Балланс классов
# Абсолютные частоты
class_counts = df_filtered['label'].value_counts()
print("Абсолютные частоты:")
print(class_counts)

# Относительные частоты (в процентах)
class_percentages = df_filtered['label'].value_counts(normalize=True) * 100
print("\nОтносительные частоты (%):")
print(class_percentages)
# Out:
# Абсолютные частоты:
# label
# auto        11990
# realty      10884
# finances    10711
# sport       10274
# Name: count, dtype: int64
#
# Относительные частоты (%):
# label
# auto        27.337605
# realty      24.815887
# finances    24.421441
# sport       23.425067
# Name: proportion, dtype: float64

# %%
df_filtered.to_csv("preresult.csv", index=False, encoding='utf-8-sig')

# %%
df_filtered = pd.read_csv('preresult.csv')

# %%
# удаляем дубликаты строк
df_filtered = df_filtered.drop_duplicates(subset=['text'], keep='first')
df_filtered.shape
# Out:
# (42155, 2)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42155 entries, 0 to 42154
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    42155 non-null  object
#  1   label   42155 non-null  object
# dtypes: object(2)
# memory usage: 658.8+ KB

# %%
print(df_filtered['label'].value_counts())
# Out:
# label
# realty      10835
# finances    10711
# auto        10344
# sport       10265
# Name: count, dtype: int64

# %%
# Делаем классы одинакового размера
min_count = df_filtered['label'].value_counts().min()
print(min_count)
# Out:
# 10265

# %%
df_balanced = (
    df_filtered.groupby('label')
      .apply(lambda x: x.sample(min_count, random_state=42))
      .reset_index(drop=True)
)
# Out:
# /tmp/ipykernel_5807/2937311911.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(min_count, random_state=42))

# %%
print(df_balanced['label'].value_counts())
# Out:
# label
# auto        10265
# finances    10265
# realty      10265
# sport       10265
# Name: count, dtype: int64

# %%
# Делим данные на test/train
from sklearn.model_selection import train_test_split

X = df_balanced['text']
y = df_balanced['label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,        # 80/20
    random_state=42,
    stratify=y
)

# %%
df_balanced.to_csv("result.csv", index=False, encoding='utf-8-sig')
